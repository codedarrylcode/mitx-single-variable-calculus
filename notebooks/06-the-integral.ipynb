# %% [markdown]
# # The integral
#
# <hr>

# %% [markdown]
# ## Mean Value Theorem (MVT)
#
# Recall that the **average rate of change** of a function $x(t)$ over an interval $[a, b]$ is:
#
# $\text{Average rate of change} = \frac{x(b) - x(a)}{b-a} = \frac{\text{Rise}}{\text{Run}}$
#
# Similarly we can represent the average rate of change geometrically by the slope of the secant line through the points $(a, x(a)), (b, x(b))$
#
# <img alt="Secant Line" src="assets/secant_line_rate_of_change.png" width="300">
#
# In contrast, the **instantaneous rate of change** of a function $x(t)$ is the derivative:
#
# $x'(t) = \lim\limits_{\Delta t \to 0} \frac{x(t+\Delta t) - x(t)}{\Delta t}$
#
# which is also geometrically represented by the slope of the tangent line through the point $(t, x(t))$
#
# ****
#
# **Definition**
#
# The **Mean Value Theorem** states that there is a point $c$, such that $a < c < b$, at which the tangent line is parallel to the secant line, i.e. the slope of both lines equal. This is true if $x(t)$ is continuous on the closed interval $[a, b]$ and differentiable on the open interval $(a, b)$.
#
# We can represent this mathetmatically as follows:
#
# $\frac{x(b) - x(a)}{b - a} = x'(c)$
#
# where the $\text{LHS}$ computes the average rate of change between the interval $[a, b]$ and the $\text{RHS}$ computes the instantaneous rate of change at point $c$.
#
# *Applying the mean value theorem*
#
# Suppose $f$ is a continuous, differentiable function. If $f'$ is never zero and $a \neq b$, then show $f(a) \neq f(b)$.
#
# $\frac{f(b)-f(a)}{b-a} = f'(c)$ for $a < c < b$ and we want to prove $f(b) - f(a)$ is never zero
#
# $f(b) - f(a) = f'(c) \cdot (b-a)$
#
# Since $f'$ and $b - a$ are non-zero then the product of $f'(c) \cdot (b-a)$ is non-zero and proves that $f(b) - f(a)$ is non-zero as well
#
# ****
#
# **Bounds, derivatives and MVT**
#
# Recall that a function $f(x)$ is increasing if whenever $a < b$ then $f(a) < f(b)$ and decreasing if vice versa.
#
# - If $x'(t) \geq 0$ for all $t \in (a, b)$, then $x(t)$ is increasing or staying the same over the closed interval, $[a, b]$
#
# - If $x'(t) \leq 0$ for all $t \in (a, b)$, then $x(t)$ is decreasing or staying the same over the closed interval, $[a, b]$
#
# - If $x'(t) = 0$ for all $t \in (a, b)$, then $x(t)$ is constant over the closed interval, $[a, b]$
#
# And the MVT gives the following consequences with strict inequalities as well:
#
# - If $x'(t) > 0$ for all $t \in (a, b)$, then $x(t)$ is strictly increasing over the closed interval, $[a, b]$
#
# - If $x'(t) < 0$ for all $t \in (a, b)$, then $x(t)$ is strictly decreasing over the closed interval, $[a, b]$
#
# *Example*
#
# Prove $e^x > 1 + x + \frac{x^2}{2}$
#
# $g(x) = e^x - (1 + x + \frac{x^2}{2})$
#
# $g(0) = 1 - (1) = 0$
#
# $g'(x) = e^x - (1+x) > 0$ for all $x > 0$
#
# ****
#
# **Bounding the average rate of change**
#
# In general, the MVT says that the average rate of change is equal to the instantaneous rate of change at some point $c$ which means that this is no larger than the maximum rate of change over the closed-interval, such that:
#
# $\frac{x(b)-x(a)}{b-a} = x'(c) \leq \max x' \leq M$ such that $M$ is the upper bound on the derivative. This is also true with the lower bound, such that:
#
# $m \leq x'(c) \leq M$ for all $c$ over the interval $(a, b)$ where $m$ is the lower bound on the derivative $x'(c)$
#
# Then the MVT implies that:
#
# $m \leq \frac{x(b)-x(a)}{b-a} \leq M$
#
# In other words, a lower bound on the derivative is also a lower bound on the average rate of change and similarly for the upper bound.
#
# Since $(b-a) > 0$, multiplying the inequality on both sides will not change the inequality signs and we get the following inequality of the total change of the function:
#
# $m \cdot (b-a) \leq x(b)-x(a) \leq M \cdot (b-a)$
#
# In other words, the total change of the function from $a \to b$ is greater than or equal to any lower bound $m$ on the derivative on the interval $(a, b)$, times the length of the interval, $(b-a)$ and it is also less than or equal to any upper bound $M$ times $(b-a)$.
#
# Sometimes we know the maximum and minimum values of $x'(t)$ and in this case we can use the lowest upper bound on the derivative and the greatest lower bound on $x'(t)$ and obtain the following inequality for the average rate of change:
#
# $\displaystyle \min _{a \leq t \leq b} x'(t) \cdot (b-a) \leq x(b)-x(a) \leq \displaystyle  \max _{a\leq t \leq b} x'(t) \cdot (b-a)$
#
# Moreover, the maximum and minimum on $x'(t)$ are the best bounds on $x'(t)$:
#
# $m \leq \displaystyle \min _{a \leq t \leq b} x'(t) \leq x'(t) \leq \max _{a\leq t \leq b} x'(t) \leq M$
#
# The MVT then gives us this in the full form:
#
# $m \cdot (b-a) \leq \displaystyle \min _{a \leq t \leq b} x'(t) \cdot (b-a) \leq x(b) - x(a) \leq \max _{a\leq t \leq b} x'(t) \cdot (b-a) \leq M \cdot (b-a)$
#
# ****
#
# **MVT's relationship with linear approximation**
#
# $\frac{\Delta f}{\Delta x} \approx f'(a)$ for $b$ near $a$ and $\Delta x = b-a$ (linear approximation)
#
# $\frac{\Delta f}{\Delta x} = f'(c)$ for some $c$ between $a$ and $b$ (MVT)
#
# <img alt="Linear Approximation vs MVT" src="assets/linear_approx_vs_MVT.png" width="500">
#
# ****
#
# ## Differentials & antiderivatives
#
# *What is a differential?*
#
# Given a function $y = f(x)$ then the differential of $y$ (*or $f$*) is $dy = f'(x) dx$ which is equivalent to the Leibniz interpretation of a derivative as a ratio of *infinitesimals (infinitely small quantity)*  $\frac{dy}{dx} = f'(x)$
#
# The idea is that even though both $dy, dx$ are infinitely small, their ratio is **not**. Their ratio is the derivative and the differential notation says that $dy$ is proportional to $dx$ with constant of proportionality $f'(x)$
#
# ****
#
# **Antiderivatives and indefinite integrals**
#
# An antiderivative of $f(x)$ is any function $F(x)$ such that, $F'(x) = f(x)$, in other words an antiderivative of a function $f(x)$ is another function whose derivative is $f(x)$
#
# $F(x) = \int f(x) dx$
#
# Another name of an antiderivative of $f$ is an *indefinite integral* of $f$ where it is ambiguous and  there are multiple possible antiderivatives to a given function, for e.g. the integral of zero is any real number number between $-\infty$ to $\infty$
#
# $\therefore$ The antiderivative or indefinite integral of $f(x)$ is a family of functions such that:
#
# $\int f(x) dx = F(x) + C$
#
# where $F(x)$ is any antiderivative of $f(x)$ and $C$ is any constant. This is such that the derivative of a function determines only the shape of the function but the shape does not change if the function is shifted up or downwards by the same constant everywhere.
#
# If $F' = G'$, then $F(x) = G(x)$ where:
#
# Then, $(F-G)' = F' - G' = 0$
#
# Hence, $F(x) - G(x) = C$
#
# $\therefore$ The indefinite integral is unique up to a point of constant $C$ and is the only ambiguity of the indefinite integral due to the MVT which guarantees that any two antiderivatives of the same function can differ only by a constant
#
# ****
#
# **Rules of integrals**
#
# *Integral of powers*
#
# Given a function $\int x^n dx$, in general the indefinite integral will be as follows:
#
# $\int x^n dx = \frac{1}{n+1} x^{n+1} + C$ when $n \neq -1$
#
# $\int \frac{dx}{x} = \ln \vert x \vert + C$ when $n = -1$
#
# *Basic integrals of trig functions*
#
# - $\int \sec^2 x \cdot dx = \tan x + c$
# - $\int \sec x \cdot \tan x \cdot dx = \sec x + c$
# - $\int \frac{dx}{\sqrt{1-x^2}} = \sin^{-1} x + c$
# - $\int \frac{dx}{1+x^2} = \tan^{-1} x + c$
#
# *First rules of integration*
#
# - $\int k \cdot f(x) dx = k \int f(x) dx$
# - $\int (f(x) + g(x)) dx = \int f(x) dx + \int g(x) dx$
# - $\int f \cdot g dx \neq (\int f dx) \cdot (\int g dx)$
# - $\int \frac{f}{g} dx \neq \frac{\int f dx}{\int g dx}$
#
# *Method of substitution*
#
# The method of substitution is the integration analogue of the chain rule.
#
# If $g(x) dx = f(u(x)) \cdot u'(x)\cdot  dx$, that is the differential $g(x) dx$ is the result of a chain rule, then:
#
# $\int g(x) dx = \int f(u(x)) u'(x) dx$
#
# $= \int f(u) du$
#
# $= F(u(x)) + C$
#
# where $F(u)$ is an antiderivative of $f(u)$
#
# - Example: $\int x^3 (x^4 + 2)^5 dx$
#
#     Let $u = x^4 + 2$ and $du = 4x^3 dx$
#
#     *Substituting into the original integral*
#
#     $\int x^3 (x^4 + 2)^5 dx = \int u^5 \cdot \frac{1}{4} du$
#
#     $= \frac{1}{24} u^6 + C = \frac{1}{24} (x^4+2)^6 + C$
#
# ****
#
# ## Differential Equations
#
# Suppose an antiderivative, $y = \int f(x) \cdot dx$, then a differential equation is $\frac{dy}{dx} = f(x)$ and the antiderivative are the solution curves to the differential equation and therefore has the same units as $y$.
#
# *Example, $(\frac{d}{dx} + x) \cdot y = 0$*
#
# where $(\frac{d}{dx} + x)$ is the annihilation operator in quantum mechanics
#
# $\frac{dy}{dx} = -xy$
#
# $\frac{dy}{y} = -x \cdot dx$
#
# $\int \frac{1}{y} \cdot dy = - \int x \cdot dx$
#
# $\ln \vert y \vert = - \frac{x^2}{2} + C$
#
# $e^{\ln y} = e^{- \frac{x^2}{2} + C}$
#
# $y = Ae^{- \frac{x^2}{2}}$ where $A = e^C$ for $y > 0$ and any $A$ and represents the normal distribution
#
# In general, if given a differential equation of the form, $\frac{dy}{dx} = f(x) \cdot g(y)$, to solve this will require **seperation** of all terms involving $x$ from terms involving $y$ and then apply anti-differentiation to solve. This works generally for the differential equations of the following form:
#
# $\frac{dy}{dx} = f(x) \cdot g(y)$
#
# $\frac{dy}{g(y)} = f(x) \cdot dx$
#
# $\int \frac{dy}{g(y)} = \int f(x) \cdot dx$
#
# ****
#
# **Families of functions**
#
# The theorem states that given $\frac{dy}{dx} = f(x) \cdot g(y)$ and an initial condition $y(a) = b$
#
# If $f, g, g'$ are continuous, then there is a unique solution curve that satisfies.
#
# *Example*
#
# $\frac{dy}{dx} = y = f(x) \cdot g(y)$ where $f(x) = 1$ and $g(y) = y$
#
# The general solution or family of functions will equals to $y = Ce^x$ where $C$ is any real number
#
# Suppose an initial condition states that $y(0) = -2$ then $y(0) = Ce^(0)$ and $\therefore C = -2$ and $y = -2e^x$ which is the unique solution given an **initial condition**
#
# ****
#
# **Slope fields**
#
# A slope field (*or a direction field*) is a diagram that helps us to visualize the information in a first order differential equation. The slope field is obtained as follows: At each point $(x, y)$, a short segment is drawn whose slope is the value of $y'$ at the point $(x,y)$.
#
# The solution curves must be tangent to the slope field at all points.
#
# <img alt="Slope Fields" src="assets/slope_fields.png" width="500">
#
# Using Euler's method, we can apply linear approximation:
#
# Given the differential equation $\frac{dy}{dx} = x + y$
#
# 1. Choose a step size $h$ (the smaller the step size, more accuracy)
#
# 2. Let $(x_0, y_0)$ be the initial condition
#
# 3. Use differential equation and step size to determine the function's value at $x_1 = x + h$:
#
#     $x_1 = x_0 + h$
#
#     $y_1 = y_0 + (x_0+y_0)\cdot h$ (*linear approximation*)
#
#
# 4. Iterate:
#
#     $x_{k+1} = x_k + h$
#
#     $y_{k+1} = y_k + (x_k + y_k) \cdot h$
#
#
# *Example*, $\frac{dy}{dx} = x + y$
#
# We want to find a solution function $f(x)$ that satisfies the differential equation and passes through the point $(0,1)$ but we don't know what the function is but we do know a value of the function and derivative so we can use linear approximation.
#
# The linear approximation takes the form
#
# $f(x) \approx f(0) + f'(0) \cdot x$
#
# $\displaystyle  =\displaystyle 1 +\left. \frac{dy}{dx}\right|_{(0,1)} x$
#
# $= 1 + x$
#
# We can use this to approximate $f(0.1) \approx 1 + 0.1 = 1.1$ and now we can step through and find the value of the derivative of the solution function using our differential equation.
#
# $\displaystyle \left. \frac{dy}{dx}\right|_{(0.1,1.1)} = 1.2$
#
# So the best linear approximation for the solution to our differential equation through the point $(0.1, 1.1)$ is given by:
#
# $f(x) \approx f(0.1) + f'(0.1) \cdot (x-0.1)$
#
# $= 1.1 + 1.2 \cdot (x - 0.1)$
#
# We can use this formula to approximate the value of $f(0.2) \approx 1.1 + 1.2 \cdot (0.2 - 0.1) = 1.22$
#
# ****

# %% [markdown]
# # Basic code
# A `minimal, reproducible example`

# %%
# Euler's method 

## Set initial condition
x, y = 0, 0

## Set step size
h = 0.1

## Iterations counter
stepcounter = 0

## Determine how many steps to take
while stepcounter < 1000:
    y=y+(x+y)*h
    x+=h
    stepcounter+=1
